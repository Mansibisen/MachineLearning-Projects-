# %% [markdown]
# #**Predicting Whether rock or mine**

# %% [markdown]
# ##importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##Importing the csv data of sonar

# %%
dataset = pd.read_csv("Copy of sonar data.csv" , header = None)
dataset.head()
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
dataset.describe()
# Out:
#                0           1           2   ...          57          58          59
# count  208.000000  208.000000  208.000000  ...  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832  ...    0.007949    0.007941    0.006507
# std      0.022991    0.032960    0.038428  ...    0.006470    0.006181    0.005031
# min      0.001500    0.000600    0.001500  ...    0.000300    0.000100    0.000600
# 25%      0.013350    0.016450    0.018950  ...    0.003600    0.003675    0.003100
# 50%      0.022800    0.030800    0.034300  ...    0.005800    0.006400    0.005300
# 75%      0.035550    0.047950    0.057950  ...    0.010350    0.010325    0.008525
# max      0.137100    0.233900    0.305900  ...    0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %%
X = dataset.iloc[:,: -1].values
y = dataset.iloc[:, -1].values

# %%
X
# Out:
# array([[0.02  , 0.0371, 0.0428, ..., 0.0084, 0.009 , 0.0032],
#        [0.0453, 0.0523, 0.0843, ..., 0.0049, 0.0052, 0.0044],
#        [0.0262, 0.0582, 0.1099, ..., 0.0164, 0.0095, 0.0078],
#        ...,
#        [0.0522, 0.0437, 0.018 , ..., 0.0138, 0.0077, 0.0031],
#        [0.0303, 0.0353, 0.049 , ..., 0.0079, 0.0036, 0.0048],
#        [0.026 , 0.0363, 0.0136, ..., 0.0036, 0.0061, 0.0115]])

# %%
y
# Out:
# array(['R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R',
#        'R', 'R', 'R', 'R', 'R', 'R', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M'],
#       dtype=object)

# %% [markdown]
# ##Spliting data to training set and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test , y_train, y_test = train_test_split(X, y , test_size =0.2 , stratify = y)

# %%
print(X_train)
# Out:
# [[0.0139 0.0222 0.0089 ... 0.0059 0.0039 0.0048]
#  [0.0129 0.0141 0.0309 ... 0.0017 0.0024 0.0029]
#  [0.0093 0.0185 0.0056 ... 0.005  0.0058 0.0025]
#  ...
#  [0.0201 0.0026 0.0138 ... 0.0024 0.0057 0.0044]
#  [0.0119 0.0582 0.0623 ... 0.0073 0.003  0.0138]
#  [0.0293 0.0378 0.0257 ... 0.0055 0.005  0.0087]]

# %%
print(X_test)
# Out:
# [[0.0516 0.0944 0.0622 ... 0.0109 0.0074 0.0078]
#  [0.0293 0.0644 0.039  ... 0.016  0.0095 0.0011]
#  [0.0378 0.0318 0.0423 ... 0.0062 0.0043 0.0053]
#  ...
#  [0.0291 0.04   0.0771 ... 0.0081 0.0139 0.0111]
#  [0.0373 0.0281 0.0232 ... 0.0054 0.0085 0.006 ]
#  [0.0231 0.0315 0.017  ... 0.0091 0.0008 0.0092]]

# %%
print(y_train)
# Out:
# ['R' 'M' 'R' 'R' 'M' 'R' 'M' 'M' 'R' 'R' 'R' 'M' 'R' 'R' 'M' 'M' 'R' 'R'
#  'R' 'M' 'R' 'M' 'R' 'M' 'R' 'M' 'M' 'R' 'M' 'M' 'M' 'R' 'R' 'R' 'M' 'M'
#  'M' 'M' 'M' 'M' 'M' 'M' 'M' 'R' 'R' 'R' 'R' 'M' 'M' 'R' 'R' 'M' 'R' 'R'
#  'M' 'M' 'M' 'M' 'M' 'M' 'M' 'M' 'R' 'R' 'R' 'R' 'M' 'M' 'R' 'M' 'R' 'M'
#  'R' 'M' 'M' 'R' 'M' 'R' 'M' 'R' 'M' 'M' 'R' 'M' 'R' 'R' 'M' 'R' 'M' 'M'
#  'M' 'R' 'M' 'R' 'M' 'M' 'R' 'M' 'M' 'R' 'R' 'M' 'R' 'M' 'M' 'M' 'M' 'M'
#  'R' 'M' 'R' 'M' 'R' 'R' 'M' 'R' 'M' 'M' 'R' 'M' 'R' 'M' 'R' 'R' 'R' 'M'
#  'M' 'M' 'R' 'R' 'M' 'R' 'M' 'R' 'M' 'R' 'M' 'M' 'R' 'R' 'M' 'R' 'R' 'M'
#  'M' 'M' 'R' 'R' 'R' 'R' 'R' 'M' 'M' 'R' 'M' 'M' 'R' 'M' 'M' 'M' 'M' 'M'
#  'R' 'R' 'R' 'R']

# %%
print(y_test)
# Out:
# ['M' 'R' 'R' 'M' 'M' 'M' 'M' 'R' 'R' 'R' 'M' 'M' 'M' 'R' 'R' 'M' 'M' 'M'
#  'R' 'R' 'R' 'R' 'M' 'M' 'M' 'R' 'R' 'M' 'M' 'R' 'R' 'R' 'M' 'M' 'M' 'M'
#  'R' 'R' 'M' 'R' 'R' 'M']

# %% [markdown]
# ## Model training

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train , y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ## predicting the test results

# %%
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array(['M', 'R', 'M', 'M', 'M', 'M', 'M', 'R', 'R', 'M', 'M', 'M', 'M',
#        'R', 'R', 'M', 'M', 'M', 'R', 'R', 'R', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'R', 'R', 'R', 'M', 'M', 'M', 'M', 'R', 'R', 'R',
#        'R', 'M', 'R'], dtype=object)

# %% [markdown]
# ## model evaluation

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , y_pred)
# Out:
# 0.8095238095238095

# %% [markdown]
# ## visualizing the problem

# %%
plt.title("Sonar data")
plt.xlabel('X- Axis')
plt.ylabel('y-Axis')
plt.scatter(X[:,0], y)
